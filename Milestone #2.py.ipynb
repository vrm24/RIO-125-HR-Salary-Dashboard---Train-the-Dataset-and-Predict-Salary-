# %% [markdown]
# # 1. Importing dataset

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
df=pd.read_csv('salary_data.csv')

# %%
#READ DATA
df.head()
# Out:
#    age         workclass  education  education-num      marital-status  \
# 0   39         State-gov  Bachelors             13       Never-married
# 1   50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2   38           Private    HS-grad              9            Divorced
# 3   53           Private       11th              7  Married-civ-spouse
# 4   28           Private  Bachelors             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country salary
# 0             0              40  United-States  <=50K
# 1             0              13  United-States  <=50K
# 2             0              40  United-States  <=50K
# 3             0              40  United-States  <=50K
# 4             0              40           Cuba  <=50K

# %%
df.tail()
# Out:
#        age     workclass   education  education-num      marital-status  \
# 32556   27       Private  Assoc-acdm             12  Married-civ-spouse
# 32557   40       Private     HS-grad              9  Married-civ-spouse
# 32558   58       Private     HS-grad              9             Widowed
# 32559   22       Private     HS-grad              9       Never-married
# 32560   52  Self-emp-inc     HS-grad              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 32556       Tech-support         Wife  White  Female             0
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical    Own-child  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 32556             0              38  United-States  <=50K
# 32557             0              40  United-States   >50K
# 32558             0              40  United-States  <=50K
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K

# %%
#CHECK DATA INFORMATION
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   education-num   32561 non-null  int64
#  4   marital-status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital-gain    32561 non-null  int64
#  10  capital-loss    32561 non-null  int64
#  11  hours-per-week  32561 non-null  int64
#  12  native-country  32561 non-null  object
#  13  salary          32561 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %%
#DESCRIBE DATA
df.describe()
# Out:
#                 age  education-num  capital-gain  capital-loss  hours-per-week
# count  32561.000000   32561.000000  32561.000000  32561.000000    32561.000000
# mean      38.581647      10.080679   1077.648844     87.303830       40.437456
# std       13.640433       2.572720   7385.292085    402.960219       12.347429
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %%
#CHECK SHAPE OF DATA
df.shape
# Out:
# (32561, 14)

# %%
#CHECK DATA COLUMNS
df.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
#CHECK UNIQUE VALUES
df.nunique()
# Out:
# age                73
# workclass           9
# education          16
# education-num      16
# marital-status      7
# occupation         15
# relationship        6
# race                5
# sex                 2
# capital-gain      119
# capital-loss       92
# hours-per-week     94
# native-country     42
# salary              2
# dtype: int64

# %% [markdown]
# # 2. EDA

# %%
df.hist(figsize=(20,15))
plt.show()

# %%
#Generates histogram specifying age column in the dataset
plt.hist(df['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(np.arange(20,100,5))
plt.rcParams['figure.figsize'] = (10,10)
plt.title('Age Distribution')
plt.show()

# %%
#generates a bar plot that effectively visualizes the distribution of education levels in the dataset
df['education'].value_counts().plot(kind = 'bar')
plt.xlabel('Education')
plt.ylabel('Count')
plt.rcParams['figure.figsize'] = (10,10)
plt.title('Education level')
plt.show()

# %%
# creates a bar plot showing the count of each category in the 'sex' column of the dataset
sns.countplot(x=df['sex'])
plt.title('gender count')
# Out:
# Text(0.5, 1.0, 'gender count')

# %%
#generates a pie chart to visualize the distribution of marital status categories in the dataset
df['marital-status'].value_counts().plot(kind = 'pie',subplots=True, autopct='%1.1f%%')
plt.rcParams['figure.figsize'] = (10,10)
plt.title('marital status')
plt.show()

# %%
# generates a pie chart to visualize the distribution of relationship categories in the dataset
df['relationship'].value_counts().plot(kind = 'pie',subplots=True, autopct='%1.1f%%')
plt.rcParams['figure.figsize'] = (10,10)
plt.title('Relationship')
plt.show()

# %%
# generates a count plot to visualize the distribution of different occupations in the dataset
sns.countplot(x=df['occupation'])
plt.xticks(rotation=90)       #xticks = sets the tickmarks on x axis
plt.title('occupation status')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 3.DATA PREPROCESSING

# %% [markdown]
# # # 3.1 HANDLING MISSING VALUES

# %%
#check null values
df.isna().sum()
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
#CHECK DATA TYPES
df.dtypes
# Out:
# age                int64
# workclass         object
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %% [markdown]
# REPLACED MISSING VALUES WITH MEAN

# %%
for i in ['capital-gain','capital-loss', 'hours-per-week']:
      df[i]=df[i].fillna(df[i].mean())

# %%
#RECHECK NULL VALUES
df.isna().sum()
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %% [markdown]
# # # 3.2 CORRELATION

# %%
corrmatrix=df.corr()
plt.subplots(figsize=(10,4))
sns.heatmap(corrmatrix,vmin=0.2,vmax=0.9,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# # 3.3 REMOVING OR MODIFYING OUTLIERS

# %% [markdown]
# OUTLIER DETECTION

# %%
num_col = df.select_dtypes(include=np.number).columns.tolist()
plt.figure(figsize=(20,30))

for i, variable in enumerate(num_col):
                     plt.subplot(5,5,i+1)
                     plt.boxplot(df[variable],whis=1.5)
                     plt.tight_layout()
                     plt.title(variable)

# %% [markdown]
# MODIFYING OUTLIERS

# %%
for i in num_col:
    Q1=df[i].quantile(0.25) # 25th quantile
    Q3=df[i].quantile(0.75)  # 75th quantile
    IQR=Q3-Q1
    Lower_Whisker = Q1 - 1.5*IQR 
    Upper_Whisker = Q3 + 1.5*IQR
    df[i] = np.clip(df[i], Lower_Whisker, Upper_Whisker)

# %%
plt.figure(figsize=(20,30))

for i, variable in enumerate(num_col):
                     plt.subplot(5,5,i+1)
                     plt.boxplot(df[variable],whis=1.5)
                     plt.tight_layout()
                     plt.title(variable)

# %%
from sklearn import preprocessing 
label= preprocessing.LabelEncoder()  
df['workclass']=label.fit_transform(df['workclass'])
df['education']=label.fit_transform(df['education'])
df['occupation']=label.fit_transform(df['occupation'])
df['sex']=label.fit_transform(df['sex'])
#df['salary']=label.fit_transform(df['salary'])
df['race']=label.fit_transform(df['race'])
df['native-country']=label.fit_transform(df['native-country'])
df['marital-status']=label.fit_transform(df['marital-status'])
df['relationship']=label.fit_transform(df['relationship'])

# %%
df
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 0       39          7          9           13.0               4           1
# 1       50          6          9           13.0               2           4
# 2       38          4         11            9.0               0           6
# 3       53          4          1            7.0               2           6
# 4       28          4          9           13.0               2          10
# ...    ...        ...        ...            ...             ...         ...
# 32556   27          4          7           12.0               2          13
# 32557   40          4         11            9.0               2           7
# 32558   58          4         11            9.0               6           1
# 32559   22          4         11            9.0               4           1
# 32560   52          5         11            9.0               2           4
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0                 1     4    1             0             0            40.0
# 1                 0     4    1             0             0            32.5
# 2                 1     4    1             0             0            40.0
# 3                 0     2    1             0             0            40.0
# 4                 5     2    0             0             0            40.0
# ...             ...   ...  ...           ...           ...             ...
# 32556             5     4    0             0             0            38.0
# 32557             0     4    1             0             0            40.0
# 32558             4     4    0             0             0            40.0
# 32559             3     4    1             0             0            32.5
# 32560             5     4    0             0             0            40.0
#
#        native-country salary
# 0                  39  <=50K
# 1                  39  <=50K
# 2                  39  <=50K
# 3                  39  <=50K
# 4                   5  <=50K
# ...               ...    ...
# 32556              39  <=50K
# 32557              39   >50K
# 32558              39  <=50K
# 32559              39  <=50K
# 32560              39   >50K
#
# [32561 rows x 14 columns]

# %% [markdown]
# # Standard Scaling

# %%
X=df.drop(columns=['salary'],axis=1)
y=df['salary']

# %%
X.describe()
# Out:
#                 age     workclass     education  education-num  \
# count  32561.000000  32561.000000  32561.000000   32561.000000
# mean      38.555603      3.868892     10.298210      10.124321
# std       13.556130      1.455960      3.870264       2.459770
# min       17.000000      0.000000      0.000000       4.500000
# 25%       28.000000      4.000000      9.000000       9.000000
# 50%       37.000000      4.000000     11.000000      10.000000
# 75%       48.000000      4.000000     12.000000      12.000000
# max       78.000000      8.000000     15.000000      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean         2.611836      6.572740      1.446362      3.665858      0.669205
# std          1.506222      4.228857      1.606771      0.848806      0.470506
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%          2.000000      3.000000      0.000000      4.000000      0.000000
# 50%          2.000000      7.000000      1.000000      4.000000      1.000000
# 75%          4.000000     10.000000      3.000000      4.000000      1.000000
# max          6.000000     14.000000      5.000000      4.000000      1.000000
#
#        capital-gain  capital-loss  hours-per-week  native-country
# count       32561.0       32561.0    32561.000000    32561.000000
# mean            0.0           0.0       41.202451       36.718866
# std             0.0           0.0        6.187005        7.823782
# min             0.0           0.0       32.500000        0.000000
# 25%             0.0           0.0       40.000000       39.000000
# 50%             0.0           0.0       40.000000       39.000000
# 75%             0.0           0.0       45.000000       39.000000
# max             0.0           0.0       52.500000       41.000000

# %%
X.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country'],
#       dtype='object')

# %%
#import library
from sklearn.preprocessing import StandardScaler

# %%
#fitting the model
scaler=StandardScaler()
X=scaler.fit_transform(X)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X = np.random.rand(32561, 13)  # Example random data
columns = ['age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'hours-per-week', 'native-country']

# Check the shape of X and columns
print("Shape of X:", X.shape)
print("Number of Columns:", len(columns))

X = X[:, :10]  # Selecting only the first 10 columns of X

# Now, create the DataFrame
df = pd.DataFrame(X, columns=columns)
# Out:
# Shape of X: (32561, 13)
# Number of Columns: 10

# %%
X=pd.DataFrame(X,columns = ['age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'hours-per-week', 'native-country'])

# %%
X
# Out:
#             age  workclass  education  marital-status  occupation  \
# 0      0.826434   0.964146   0.945326        0.199964    0.569863
# 1      0.451653   0.172623   0.618766        0.905208    0.498824
# 2      0.685039   0.346313   0.299565        0.674609    0.413731
# 3      0.962591   0.946654   0.266806        0.667268    0.659781
# 4      0.586203   0.808493   0.712492        0.680470    0.213352
# ...         ...        ...        ...             ...         ...
# 32556  0.664069   0.481045   0.665749        0.986413    0.787054
# 32557  0.371170   0.673777   0.315910        0.769836    0.390947
# 32558  0.393225   0.694241   0.912664        0.954265    0.794799
# 32559  0.133804   0.932669   0.709265        0.400924    0.034833
# 32560  0.618394   0.782335   0.799704        0.617872    0.613777
#
#        relationship      race       sex  hours-per-week  native-country
# 0          0.186865  0.688232  0.758870        0.651655        0.081929
# 1          0.787053  0.154701  0.726957        0.297762        0.393666
# 2          0.134095  0.722931  0.002376        0.566044        0.848355
# 3          0.479091  0.780931  0.895653        0.435243        0.235465
# 4          0.142320  0.395880  0.382803        0.710492        0.917361
# ...             ...       ...       ...             ...             ...
# 32556      0.766194  0.346131  0.189299        0.046620        0.056183
# 32557      0.611038  0.564601  0.565531        0.613887        0.112473
# 32558      0.285657  0.261273  0.151198        0.232745        0.777306
# 32559      0.232181  0.379799  0.139973        0.032104        0.694117
# 32560      0.574005  0.149653  0.966260        0.512482        0.504086
#
# [32561 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# # Logistic regression

# %%
#import logistic regression
from sklearn.linear_model import LogisticRegression
lor=LogisticRegression()
lor_model=lor.fit(X_train,y_train)
y_predict_lor=lor_model.predict(X_test)

# %%
y_predict_lor
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %% [markdown]
# confusion matrix

# %%
#import confusion matrix
from sklearn.metrics import confusion_matrix

# %%
#confusion matrix
confusion_matrix(y_test,y_predict_lor)
# Out:
# array([[7455,    0],
#        [2314,    0]], dtype=int64)

# %% [markdown]
# precision,accuracy and recall score

# %%
#import precision score and recall score
from sklearn.metrics import precision_score,recall_score

# %%
#precision score
precision_score(y_test,y_predict_lor,pos_label=1,average='micro')
# Out:
# 0.7631282628723514

# %%
#recallscore
recall_score(y_test,y_predict_lor,pos_label=1,average='micro')
# Out:
# 0.7631282628723514

# %%
#check accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict_lor)
# Out:
# 0.7631282628723514

# %%
R1=accuracy_score(y_test,y_predict_lor)*100
R1
# Out:
# 76.31282628723514
